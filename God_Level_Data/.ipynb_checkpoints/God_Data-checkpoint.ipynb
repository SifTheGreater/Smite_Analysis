# %% [markdown]
# # Gods Stats EDA

# %% [markdown]
# This notebook is the exploratory analysis for the stats of all of the gods in smite.
#
# I will look at the structure of the data pulled directly from the API clean it up and see if there are any interesting high level views before I work on some ideas.
#
# Im hoping to keep this notebook very standardized to accomidate new gods as they are introduced to the game

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
from pathlib import Path
import os

pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Pulling in the main table data

# %%
path = os.getcwd()
parent = os.path.dirname(path)
sqliteConnection = sqlite3.connect('{}/API_Interaction/Smite.db'.format(parent))
cursor = sqliteConnection.cursor()

# %%
sql_command = """
SELECT * FROM Gods """

df = pd.read_sql_query(sql_command, sqliteConnection)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### First lets check the data

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#              Ability1             Ability2         Ability3  \
# 0  Shield of Achilles        Radiant Glory     Combat Dodge
# 1       Noxious Fumes           Flame Wave   Path of Flames
# 2                Hive                Swarm            Honey
# 3        Undead Surge     Corpse Explosion  Fleeting Breath
# 4     Divine Presence  Heavenly Reflection  Glorious Charge
#
#              Ability4             Ability5  AbilityId1  AbilityId2  \
# 0        Fatal Strike     Gift of the Gods       15676       15677
# 1           Rain Fire           Combustion        7812        7811
# 2             Stinger                Bees!        9385        9381
# 3    Empty the Crypts        Hollow Ground       11348       16364
# 4  Dazzling Offensive  Illuminating Strike       12046       12055
#
#    AbilityId3  AbilityId4  AbilityId5  AttackSpeed  AttackSpeedPerLevel  \
# 0       15679       15680       15678         0.95                0.012
# 1        7818        7824        7822         1.00                0.012
# 2        9423        9393        9380         0.95                0.016
# 3       11394       11364       11361         0.86                0.008
# 4       12047       12049       12072         1.00                0.014
#
#   AutoBanned Cons  HP5PerLevel  Health  HealthPerFive  HealthPerLevel  \
# 0          n              0.75     665              9              89
# 1          n              0.47     504              7              75
# 2          n              0.71     630              7              77
# 3          n              0.45     630              6              79
# 4          n              0.80     672              8              89
#
#                                                 Lore  MP5PerLevel  \
# 0  King Agamemnon brought his fury to bear agains...         0.39
# 1  There are few elements as destructive or as pu...         0.37
# 2  It is said that history is written by the vict...         0.38
# 3  Buried beneath the crust of the world descends...         0.42
# 4  As the first rays of dawn cross the horizon, b...         0.40
#
#    MagicProtection  MagicProtectionPerLevel  MagicalPower  \
# 0             38.4                      1.2             0
# 1             38.4                      1.2           170
# 2             38.4                      1.2             0
# 3             38.4                      1.2           175
# 4             38.4                      1.2             0
#
#    MagicalPowerPerLevel  Mana  ManaPerFive  ManaPerLevel          Name  \
# 0                   0.0   205          4.7            35      Achilles
# 1                   7.5   255          4.7            45          Agni
# 2                   0.0   230          4.4            40  Ah Muzen Cab
# 3                   7.5   265          4.9            55       Ah Puch
# 4                   0.0   220          4.8            35     Amaterasu
#
#   OnFreeRotation  Pantheon  PhysicalPower  PhysicalPowerPerLevel  \
# 0                    Greek             38                    2.0
# 1                    Hindu              0                    0.0
# 2                     Maya             38                    2.2
# 3                     Maya              0                    0.0
# 4                 Japanese             39                    2.0
#
#    PhysicalProtection  PhysicalProtectionPerLevel  \
# 0                23.8                         3.2
# 1                15.4                         2.8
# 2                16.8                         3.2
# 3                18.2                         2.9
# 4                25.2                         3.2
#
#                                        Pros    Roles  Speed  \
# 0  High Single Target Damage, High Mobility  Warrior    370
# 1                          High Area Damage     Mage    355
# 2    High Movement Speed, High Attack Speed   Hunter    365
# 3                          High Area Damage     Mage    365
# 4           High Area Damage, High Mobility  Warrior    375
#
#                     Title              Type  \
# 0  Hero of the Trojan War   Melee, Physical
# 1             God of Fire   Ranged, Magical
# 2             God of Bees  Ranged, Physical
# 3   Horrific God of Decay   Ranged, Magical
# 4       The Shining Light   Melee, Physical
#
#                                      godAbility1_URL  \
# 0  https://webcdn.hirezstudios.com/smite/god-abil...
# 1  https://webcdn.hirezstudios.com/smite/god-abil...
# 2  https://webcdn.hirezstudios.com/smite/god-abil...
# 3  https://webcdn.hirezstudios.com/smite/god-abil...
# 4  https://webcdn.hirezstudios.com/smite/god-abil...
#
#                                      godAbility2_URL  \
# 0  https://webcdn.hirezstudios.com/smite/god-abil...
# 1  https://webcdn.hirezstudios.com/smite/god-abil...
# 2  https://webcdn.hirezstudios.com/smite/god-abil...
# 3  https://webcdn.hirezstudios.com/smite/god-abil...
# 4  https://webcdn.hirezstudios.com/smite/god-abil...
#
#                                      godAbility3_URL  \
# 0  https://webcdn.hirezstudios.com/smite/god-abil...
# 1  https://webcdn.hirezstudios.com/smite/god-abil...
# 2  https://webcdn.hirezstudios.com/smite/god-abil...
# 3  https://webcdn.hirezstudios.com/smite/god-abil...
# 4  https://webcdn.hirezstudios.com/smite/god-abil...
#
#                                      godAbility4_URL  \
# 0  https://webcdn.hirezstudios.com/smite/god-abil...
# 1  https://webcdn.hirezstudios.com/smite/god-abil...
# 2  https://webcdn.hirezstudios.com/smite/god-abil...
# 3  https://webcdn.hirezstudios.com/smite/god-abil...
# 4  https://webcdn.hirezstudios.com/smite/god-abil...
#
#                                      godAbility5_URL  \
# 0  https://webcdn.hirezstudios.com/smite/god-abil...
# 1  https://webcdn.hirezstudios.com/smite/god-abil...
# 2  https://webcdn.hirezstudios.com/smite/god-abil...
# 3  https://webcdn.hirezstudios.com/smite/god-abil...
# 4  https://webcdn.hirezstudios.com/smite/god-abil...
#
#                                          godCard_URL  \
# 0  https://webcdn.hirezstudios.com/smite/god-card...
# 1  https://webcdn.hirezstudios.com/smite/god-card...
# 2  https://webcdn.hirezstudios.com/smite/god-card...
# 3  https://webcdn.hirezstudios.com/smite/god-card...
# 4  https://webcdn.hirezstudios.com/smite/god-card...
#
#                                          godIcon_URL    id latestGod ret_msg
# 0  https://webcdn.hirezstudios.com/smite/god-icon...  3492         n    None
# 1  https://webcdn.hirezstudios.com/smite/god-icon...  1737         n    None
# 2  https://webcdn.hirezstudios.com/smite/god-icon...  1956         n    None
# 3  https://webcdn.hirezstudios.com/smite/god-icon...  2056         n    None
# 4  https://webcdn.hirezstudios.com/smite/god-icon...  2110         n    None

# %%
print(df.shape)
# Out:
# (121, 49)

# %%
df.describe()
# Out:
#          AbilityId1    AbilityId2    AbilityId3    AbilityId4    AbilityId5  \
# count    121.000000    121.000000    121.000000    121.000000    121.000000
# mean   12631.322314  12717.082645  12824.380165  12633.462810  12728.570248
# std     4166.627648   4157.678640   4193.271053   4162.500675   4100.813630
# min     7305.000000   7324.000000   7307.000000   7308.000000   7547.000000
# 25%     9004.000000   9013.000000   9228.000000   9096.000000   9188.000000
# 50%    11596.000000  11731.000000  11738.000000  11492.000000  11831.000000
# 75%    15877.000000  16279.000000  16203.000000  15909.000000  15869.000000
# max    21904.000000  21905.000000  21906.000000  21907.000000  21912.000000
#
#        AttackSpeed  AttackSpeedPerLevel  HP5PerLevel      Health  \
# count   121.000000           121.000000   121.000000  121.000000
# mean      0.964215             0.013050     0.650165  624.619835
# std       0.050312             0.004477     0.130722   61.296718
# min       0.850000             0.000000     0.430000  504.000000
# 25%       0.950000             0.010000     0.500000  560.000000
# 50%       1.000000             0.012000     0.690000  637.000000
# 75%       1.000000             0.016000     0.720000  679.000000
# max       1.050000             0.024000     0.900000  714.000000
#
#        HealthPerFive  HealthPerLevel  MP5PerLevel  MagicProtection  \
# count     121.000000      121.000000   121.000000     1.210000e+02
# mean        7.595041       84.438017     0.384711     3.840000e+01
# std         1.215034        8.711958     0.077342     7.134972e-15
# min         5.000000       70.000000     0.000000     3.840000e+01
# 25%         7.000000       79.000000     0.370000     3.840000e+01
# 50%         8.000000       82.000000     0.400000     3.840000e+01
# 75%         8.000000       89.000000     0.430000     3.840000e+01
# max        10.000000      109.000000     0.600000     3.840000e+01
#
#        MagicProtectionPerLevel  MagicalPower  MagicalPowerPerLevel  \
# count             1.210000e+02    121.000000            121.000000
# mean              1.200000e+00     82.809917              3.665289
# std               2.229679e-16     88.444645              3.965811
# min               1.200000e+00      0.000000              0.000000
# 25%               1.200000e+00      0.000000              0.000000
# 50%               1.200000e+00      0.000000              0.000000
# 75%               1.200000e+00    175.000000              7.500000
# max               1.200000e+00    200.000000             12.000000
#
#              Mana  ManaPerFive  ManaPerLevel  PhysicalPower  \
# count  121.000000   121.000000    121.000000     121.000000
# mean   228.107438     4.491736     39.900826      20.057851
# std     38.852242     0.694932      8.526825      19.048752
# min      0.000000     0.000000      0.000000       0.000000
# 25%    205.000000     4.400000     35.000000       0.000000
# 50%    225.000000     4.600000     38.000000      35.000000
# 75%    245.000000     4.800000     41.000000      38.000000
# max    350.000000     5.500000     58.000000      41.000000
#
#        PhysicalPowerPerLevel  PhysicalProtection  PhysicalProtectionPerLevel  \
# count             121.000000          121.000000                  121.000000
# mean                1.208926           19.680992                    3.135537
# std                 1.157270            5.285804                    0.208910
# min                 0.000000           11.200000                    2.700000
# 25%                 0.000000           15.400000                    3.000000
# 50%                 2.000000           18.200000                    3.200000
# 75%                 2.250000           25.200000                    3.200000
# max                 3.000000           32.200000                    3.800000
#
#             Speed           id
# count  121.000000   121.000000
# mean   367.033058  2421.057851
# std      6.554812   822.753277
# min    355.000000  1649.000000
# 25%    360.000000  1872.000000
# 50%    365.000000  2037.000000
# 75%    375.000000  3344.000000
# max    381.000000  4075.000000

# %%
df.describe(exclude=[np.number])
# Out:
#                   Ability1       Ability2            Ability3      Ability4  \
# count                  121            121                 121           121
# unique                 121            121                 120           121
# top     Shield of Achilles  Radiant Glory  72 Transformations  Fatal Strike
# freq                     1              1                   2             1
#
#                 Ability5 AutoBanned Cons  \
# count                121        121  121
# unique               121          2    1
# top     Gift of the Gods          n
# freq                   1        120  121
#
#                                                      Lore      Name  \
# count                                                 121       121
# unique                                                121       121
# top     King Agamemnon brought his fury to bear agains...  Achilles
# freq                                                    1         1
#
#        OnFreeRotation Pantheon              Pros Roles  \
# count             121      121               121   121
# unique              2       16                39     5
# top                      Greek  High Area Damage  Mage
# freq              116       22                19    36
#
#                          Title             Type  \
# count                      121              121
# unique                     121                5
# top     Hero of the Trojan War  Melee, Physical
# freq                         1               43
#
#                                           godAbility1_URL  \
# count                                                 121
# unique                                                121
# top     https://webcdn.hirezstudios.com/smite/god-abil...
# freq                                                    1
#
#                                           godAbility2_URL  \
# count                                                 121
# unique                                                121
# top     https://webcdn.hirezstudios.com/smite/god-abil...
# freq                                                    1
#
#                                           godAbility3_URL  \
# count                                                 121
# unique                                                120
# top     https://webcdn.hirezstudios.com/smite/god-abil...
# freq                                                    2
#
#                                           godAbility4_URL  \
# count                                                 121
# unique                                                121
# top     https://webcdn.hirezstudios.com/smite/god-abil...
# freq                                                    1
#
#                                           godAbility5_URL  \
# count                                                 121
# unique                                                121
# top     https://webcdn.hirezstudios.com/smite/god-abil...
# freq                                                    1
#
#                                               godCard_URL  \
# count                                                 121
# unique                                                121
# top     https://webcdn.hirezstudios.com/smite/god-card...
# freq                                                    1
#
#                                               godIcon_URL latestGod ret_msg
# count                                                 121       121       0
# unique                                                121         2       0
# top     https://webcdn.hirezstudios.com/smite/god-icon...         n     NaN
# freq                                                    1       120     NaN

# %% [markdown]
# ### Now lets remove un-needed columns and reformat others to better suit our needs

# %% [markdown]
# #### Removing the columns that dont really tell us anything (abilty name lore ect.)

# %%
df_main = df[['AttackSpeed', 'AttackSpeedPerLevel', 'Cons', 'HP5PerLevel', 'Health', 'HealthPerFive', 'HealthPerLevel', 'MP5PerLevel', 'MagicProtection', 'MagicProtectionPerLevel', 'MagicalPower', 'MagicalPowerPerLevel', 'Mana', 'ManaPerFive', 'ManaPerLevel', 'Name', 'PhysicalPower', 'PhysicalPowerPerLevel', 'PhysicalProtection', 'PhysicalProtectionPerLevel', 'Pros', 'Roles', 'Speed', 'Type']]
df_main.head()
# Out:
#    AttackSpeed  AttackSpeedPerLevel Cons  HP5PerLevel  Health  HealthPerFive  \
# 0         0.95                0.012              0.75     665              9
# 1         1.00                0.012              0.47     504              7
# 2         0.95                0.016              0.71     630              7
# 3         0.86                0.008              0.45     630              6
# 4         1.00                0.014              0.80     672              8
#
#    HealthPerLevel  MP5PerLevel  MagicProtection  MagicProtectionPerLevel  \
# 0              89         0.39             38.4                      1.2
# 1              75         0.37             38.4                      1.2
# 2              77         0.38             38.4                      1.2
# 3              79         0.42             38.4                      1.2
# 4              89         0.40             38.4                      1.2
#
#    MagicalPower  MagicalPowerPerLevel  Mana  ManaPerFive  ManaPerLevel  \
# 0             0                   0.0   205          4.7            35
# 1           170                   7.5   255          4.7            45
# 2             0                   0.0   230          4.4            40
# 3           175                   7.5   265          4.9            55
# 4             0                   0.0   220          4.8            35
#
#            Name  PhysicalPower  PhysicalPowerPerLevel  PhysicalProtection  \
# 0      Achilles             38                    2.0                23.8
# 1          Agni              0                    0.0                15.4
# 2  Ah Muzen Cab             38                    2.2                16.8
# 3       Ah Puch              0                    0.0                18.2
# 4     Amaterasu             39                    2.0                25.2
#
#    PhysicalProtectionPerLevel                                      Pros  \
# 0                         3.2  High Single Target Damage, High Mobility
# 1                         2.8                          High Area Damage
# 2                         3.2    High Movement Speed, High Attack Speed
# 3                         2.9                          High Area Damage
# 4                         3.2           High Area Damage, High Mobility
#
#      Roles  Speed              Type
# 0  Warrior    370   Melee, Physical
# 1     Mage    355   Ranged, Magical
# 2   Hunter    365  Ranged, Physical
# 3     Mage    365   Ranged, Magical
# 4  Warrior    375   Melee, Physical

# %% [markdown]
# #### Taking some of the info out of columns and seprating them into differnt points

# %%
df_main[['Range','Damage_Type']] = df.Type.str.split(expand=True)

## wrouadabout way of getting past there being different amounts of pros per god
df_temp = df_main.Pros.str.split(',', expand=True)
df_temp.columns = ['Pro{}'.format(x+1) for x in df_temp.columns]
df_temp
df_main = df_main.join(df_temp)

# %%
df_main.head()
# Out:
#    AttackSpeed  AttackSpeedPerLevel Cons  HP5PerLevel  Health  HealthPerFive  \
# 0         0.95                0.012              0.75     665              9
# 1         1.00                0.012              0.47     504              7
# 2         0.95                0.016              0.71     630              7
# 3         0.86                0.008              0.45     630              6
# 4         1.00                0.014              0.80     672              8
#
#    HealthPerLevel  MP5PerLevel  MagicProtection  MagicProtectionPerLevel  \
# 0              89         0.39             38.4                      1.2
# 1              75         0.37             38.4                      1.2
# 2              77         0.38             38.4                      1.2
# 3              79         0.42             38.4                      1.2
# 4              89         0.40             38.4                      1.2
#
#    MagicalPower  MagicalPowerPerLevel  Mana  ManaPerFive  ManaPerLevel  \
# 0             0                   0.0   205          4.7            35
# 1           170                   7.5   255          4.7            45
# 2             0                   0.0   230          4.4            40
# 3           175                   7.5   265          4.9            55
# 4             0                   0.0   220          4.8            35
#
#            Name  PhysicalPower  PhysicalPowerPerLevel  PhysicalProtection  \
# 0      Achilles             38                    2.0                23.8
# 1          Agni              0                    0.0                15.4
# 2  Ah Muzen Cab             38                    2.2                16.8
# 3       Ah Puch              0                    0.0                18.2
# 4     Amaterasu             39                    2.0                25.2
#
#    PhysicalProtectionPerLevel                                      Pros  \
# 0                         3.2  High Single Target Damage, High Mobility
# 1                         2.8                          High Area Damage
# 2                         3.2    High Movement Speed, High Attack Speed
# 3                         2.9                          High Area Damage
# 4                         3.2           High Area Damage, High Mobility
#
#      Roles  Speed              Type    Range Damage_Type  \
# 0  Warrior    370   Melee, Physical   Melee,    Physical
# 1     Mage    355   Ranged, Magical  Ranged,     Magical
# 2   Hunter    365  Ranged, Physical  Ranged,    Physical
# 3     Mage    365   Ranged, Magical  Ranged,     Magical
# 4  Warrior    375   Melee, Physical   Melee,    Physical
#
#                         Pro1                Pro2  Pro3
# 0  High Single Target Damage       High Mobility  None
# 1           High Area Damage                None  None
# 2        High Movement Speed   High Attack Speed  None
# 3           High Area Damage                None  None
# 4           High Area Damage       High Mobility  None

# %% [markdown]
# #### Some columns should be brought together id magical and physical power

# %%
## call it this as thats what the stat represents in game
## magical side is divided by 5 as in game the final number is 20% of the damage
df_main['AutoAttackDamage'] = df_main.PhysicalPower + df_main.MagicalPower/5
df_main['AutoAttackDamagePerLevel'] = df_main.PhysicalPowerPerLevel + df_main.MagicalPowerPerLevel/5
df_main
# Out:
#      AttackSpeed  AttackSpeedPerLevel Cons  HP5PerLevel  Health  \
# 0           0.95                0.012              0.75     665
# 1           1.00                0.012              0.47     504
# 2           0.95                0.016              0.71     630
# 3           0.86                0.008              0.45     630
# 4           1.00                0.014              0.80     672
# ..           ...                  ...  ...          ...     ...
# 116         1.00                0.012              0.70     686
# 117         0.85                0.010              0.90     714
# 118         1.00                0.012              0.47     560
# 119         0.95                0.009              0.45     532
# 120         0.86                0.009              0.44     630
#
#      HealthPerFive  HealthPerLevel  MP5PerLevel  MagicProtection  \
# 0                9              89         0.39             38.4
# 1                7              75         0.37             38.4
# 2                7              77         0.38             38.4
# 3                6              79         0.42             38.4
# 4                8              89         0.40             38.4
# ..             ...             ...          ...              ...
# 116              6             100         0.00             38.4
# 117              8             109         0.40             38.4
# 118              7              81         0.44             38.4
# 119              6              75         0.45             38.4
# 120              6              89         0.45             38.4
#
#      MagicProtectionPerLevel  MagicalPower  MagicalPowerPerLevel  Mana  \
# 0                        1.2             0                  0.00   205
# 1                        1.2           170                  7.50   255
# 2                        1.2             0                  0.00   230
# 3                        1.2           175                  7.50   265
# 4                        1.2             0                  0.00   220
# ..                       ...           ...                   ...   ...
# 116                      1.2           170                  7.50     0
# 117                      1.2           190                  7.75   200
# 118                      1.2           175                  7.50   280
# 119                      1.2           175                  7.50   245
# 120                      1.2           165                  7.50   250
#
#      ManaPerFive  ManaPerLevel          Name  PhysicalPower  \
# 0            4.7            35      Achilles             38
# 1            4.7            45          Agni              0
# 2            4.4            40  Ah Muzen Cab             38
# 3            4.9            55       Ah Puch              0
# 4            4.8            35     Amaterasu             39
# ..           ...           ...           ...            ...
# 116          0.0             0        Yemoja              0
# 117          4.5            32          Ymir              0
# 118          4.7            55      Yu Huang              0
# 119          4.6            44          Zeus              0
# 120          4.8            47     Zhong Kui              0
#
#      PhysicalPowerPerLevel  PhysicalProtection  PhysicalProtectionPerLevel  \
# 0                      2.0                23.8                         3.2
# 1                      0.0                15.4                         2.8
# 2                      2.2                16.8                         3.2
# 3                      0.0                18.2                         2.9
# 4                      2.0                25.2                         3.2
# ..                     ...                 ...                         ...
# 116                    0.0                26.6                         3.2
# 117                    0.0                32.2                         3.6
# 118                    0.0                16.8                         3.2
# 119                    0.0                11.2                         2.9
# 120                    0.0                11.2                         2.8
#
#                                          Pros     Roles  Speed  \
# 0    High Single Target Damage, High Mobility   Warrior    370
# 1                            High Area Damage      Mage    355
# 2      High Movement Speed, High Attack Speed    Hunter    365
# 3                            High Area Damage      Mage    365
# 4             High Area Damage, High Mobility   Warrior    375
# ..                                        ...       ...    ...
# 116                              High Sustain  Guardian    365
# 117          High Crowd Control, High Defense  Guardian    370
# 118                          High Area Damage      Mage    355
# 119                          High Area Damage      Mage    360
# 120    High Area Damage, Medium Crowd Control      Mage    360
#
#                  Type    Range Damage_Type                       Pro1  \
# 0     Melee, Physical   Melee,    Physical  High Single Target Damage
# 1     Ranged, Magical  Ranged,     Magical           High Area Damage
# 2    Ranged, Physical  Ranged,    Physical        High Movement Speed
# 3     Ranged, Magical  Ranged,     Magical           High Area Damage
# 4     Melee, Physical   Melee,    Physical           High Area Damage
# ..                ...      ...         ...                        ...
# 116   Ranged, Magical  Ranged,     Magical               High Sustain
# 117    Melee, Magical   Melee,     Magical         High Crowd Control
# 118   Ranged, Magical  Ranged,     Magical           High Area Damage
# 119   Ranged, Magical  Ranged,     Magical           High Area Damage
# 120   Ranged, Magical  Ranged,     Magical           High Area Damage
#
#                       Pro2  Pro3  AutoAttackDamage  AutoAttackDamagePerLevel
# 0            High Mobility  None              38.0                      2.00
# 1                     None  None              34.0                      1.50
# 2        High Attack Speed  None              38.0                      2.20
# 3                     None  None              35.0                      1.50
# 4            High Mobility  None              39.0                      2.00
# ..                     ...   ...               ...                       ...
# 116                   None  None              34.0                      1.50
# 117           High Defense  None              38.0                      1.55
# 118                   None  None              35.0                      1.50
# 119                   None  None              35.0                      1.50
# 120   Medium Crowd Control  None              33.0                      1.50
#
# [121 rows x 31 columns]

# %% [markdown]
# #### Lets re-order the columns into a much nicer arrangement

# %%
df_ordered = df_main[['Name', 'Damage_Type', 'Roles', 'Range', 'Pro1', 'Pro2', 'Pro3', 'Health', 'HealthPerLevel', 'HealthPerFive', 'HP5PerLevel', 'Mana', 'ManaPerLevel', 'ManaPerFive', 'MP5PerLevel', 'PhysicalProtection', 'PhysicalProtectionPerLevel', 'MagicProtection', 'MagicProtectionPerLevel', 'AttackSpeed', 'AttackSpeedPerLevel', 'AutoAttackDamage', 'AutoAttackDamagePerLevel', 'Speed']]
# also use this as a time to drop some columns

# %%
df_ordered.head()
# Out:
#            Name Damage_Type    Roles    Range                       Pro1  \
# 0      Achilles    Physical  Warrior   Melee,  High Single Target Damage
# 1          Agni     Magical     Mage  Ranged,           High Area Damage
# 2  Ah Muzen Cab    Physical   Hunter  Ranged,        High Movement Speed
# 3       Ah Puch     Magical     Mage  Ranged,           High Area Damage
# 4     Amaterasu    Physical  Warrior   Melee,           High Area Damage
#
#                  Pro2  Pro3  Health  HealthPerLevel  HealthPerFive  \
# 0       High Mobility  None     665              89              9
# 1                None  None     504              75              7
# 2   High Attack Speed  None     630              77              7
# 3                None  None     630              79              6
# 4       High Mobility  None     672              89              8
#
#    HP5PerLevel  Mana  ManaPerLevel  ManaPerFive  MP5PerLevel  \
# 0         0.75   205            35          4.7         0.39
# 1         0.47   255            45          4.7         0.37
# 2         0.71   230            40          4.4         0.38
# 3         0.45   265            55          4.9         0.42
# 4         0.80   220            35          4.8         0.40
#
#    PhysicalProtection  PhysicalProtectionPerLevel  MagicProtection  \
# 0                23.8                         3.2             38.4
# 1                15.4                         2.8             38.4
# 2                16.8                         3.2             38.4
# 3                18.2                         2.9             38.4
# 4                25.2                         3.2             38.4
#
#    MagicProtectionPerLevel  AttackSpeed  AttackSpeedPerLevel  \
# 0                      1.2         0.95                0.012
# 1                      1.2         1.00                0.012
# 2                      1.2         0.95                0.016
# 3                      1.2         0.86                0.008
# 4                      1.2         1.00                0.014
#
#    AutoAttackDamage  AutoAttackDamagePerLevel  Speed
# 0              38.0                       2.0    370
# 1              34.0                       1.5    355
# 2              38.0                       2.2    365
# 3              35.0                       1.5    365
# 4              39.0                       2.0    375

# %% [markdown]
# #### Now are dataset is nice and clean we will use this going forward

# %%
dataset = df_ordered

# %% [markdown]
# ## Some EDA

# %% [markdown]
# ### lets see how some of the stats are distributed

# %%
fig, ax = plt.subplots(4, 4, figsize=(20,15)) 

fig.suptitle('histograms of All stats')

for i in range(0, 4):
    for j in range(0, 4):
        k = i*4 + j + 7
        ax[i, j].set_title(dataset.columns[k])
        ax[i, j].hist(dataset.iloc[:, k].values, 20)

# %%
## one more to show speed stat
fig1, ax1 = plt.subplots(1, 1, figsize=(4,3))

ax1.hist(dataset.iloc[:, 23].values, 20)
ax1.set_title(dataset.columns[23])
# Out:
# Text(0.5, 1.0, 'Speed')

# %% [markdown]
# For furture plots seeing as magicl prot and prot per level are the same regardless of who you are we can ignore them. Will probably just ignore one so I can keep the full overlook of each stat in the one grid.

# %% [markdown]
# ### Lets now look at it over some of the catagorical lenses like Role and Damage Type

# %%
stats = ['Health', 'HealthPerLevel', 'HealthPerFive', 'HP5PerLevel', 'Mana', 'ManaPerLevel', 'ManaPerFive', 'MP5PerLevel', 'PhysicalProtection', 'PhysicalProtectionPerLevel', 'AttackSpeed', 'AttackSpeedPerLevel', 'AutoAttackDamage', 'AutoAttackDamagePerLevel', 'Speed']

# %%
def Plot_stat_Role(k):
    fig, ax = plt.subplots(1, 5, figsize=(25,5)) 

    min_ = dataset[k].min()
    max_ = dataset[k].max()

    A = dataset[k][dataset.Roles=='Warrior'].values
    B = dataset[k][dataset.Roles=='Assassin'].values
    C = dataset[k][dataset.Roles=='Mage'].values
    D = dataset[k][dataset.Roles=='Guardian'].values
    E = dataset[k][dataset.Roles=='Hunter'].values
    data = [A, B, C, D, E]
    labels = ['Warrior', 'Assasin', 'Mage', 'Guardian' , 'Hunter']
    color = ['Red', 'Yellow', 'Blue', 'Green', 'Orange']

    for i, x in enumerate(data):
        ax[i].set_xlim(min_, max_)
        ax[i].set_title(labels[i])
        ax[i].hist(x, len(x), color = color[i])
        
    plt.show()

# %%
Plot_stat_Role('AutoAttackDamagePerLevel')

# %%
for stat in stats:
    print(stat)
    Plot_stat_Role(stat)
# Out:
# Health
# HealthPerLevel
# HealthPerFive
# HP5PerLevel
# Mana
# ManaPerLevel
# ManaPerFive
# MP5PerLevel
# PhysicalProtection
# PhysicalProtectionPerLevel
# AttackSpeed
# AttackSpeedPerLevel
# AutoAttackDamage
# AutoAttackDamagePerLevel
# Speed

# %% [markdown]
# ##### Role or "Class" as it is in game is one of the more intersting ones
#
# we can see some clear divides in what some calsses do over others, for example look at the auto attack damage per level
#
# ![alt text](images/AAPL.jpeg "")
#
# Here we can clearly see that hunters are by far the best class for increasing there auto attack damage as the game progresses and on the otherhand mages are the worst. This makes sense when you realise that the games classes are designed around architypes and hunters archetype is "Do a lot of consistent (Auto Attack) Damage Late Game (when the game is nearing the end)
#
# Its also worth noting that there are some outliers in each class for example for the mage class there are a few mages that have seemingly higher Physical Protections than the others, namely Nox, Hades and baron. This is because these characters are designed to be more tanky versions of the general mage class, but they lack the general other traits of a guardian.
#
# ##### Lets see if there are any more patterns from the other traits

# %%
dataset[dataset.Roles == 'Mage'].sort_values(by = 'AutoAttackDamagePerLevel')
# Out:
#               Name Damage_Type Roles    Range                       Pro1  \
# 66        Kukulkan     Magical  Mage  Ranged,           High Area Damage
# 54            Hera     Magical  Mage  Ranged,           High Area Damage
# 51           He Bo     Magical  Mage  Ranged,           High Area Damage
# 60           Janus     Magical  Mage  Ranged,           High Area Damage
# 28         Chang'e     Magical  Mage  Ranged,               High Sustain
# 99             Sol     Magical  Mage  Ranged,  High Single Target Damage
# 93          Scylla     Magical  Mage  Ranged,           High Area Damage
# 8        Aphrodite     Magical  Mage  Ranged,               High Sustain
# 108         Tiamat     Magical  Mage  Ranged,           High Area Damage
# 89          Raijin     Magical  Mage  Ranged,                     Pusher
# 88              Ra     Magical  Mage  Ranged,               High Sustain
# 87        Poseidon     Magical  Mage  Ranged,           High Area Damage
# 81           Nu Wa     Magical  Mage  Ranged,                     Pusher
# 113         Vulcan     Magical  Mage  Ranged,           High Area Damage
# 80             Nox     Magical  Mage  Ranged,         High Crowd Control
# 118       Yu Huang     Magical  Mage  Ranged,           High Area Damage
# 107          Thoth     Magical  Mage  Ranged,           High Area Damage
# 74   Morgan Le Fay     Magical  Mage  Ranged,           High Area Damage
# 1             Agni     Magical  Mage  Ranged,           High Area Damage
# 119           Zeus     Magical  Mage  Ranged,           High Area Damage
# 3          Ah Puch     Magical  Mage  Ranged,           High Area Damage
# 6           Anubis     Magical  Mage  Ranged,           High Area Damage
# 17       Baba Yaga     Magical  Mage  Ranged,           High Area Damage
# 20    Baron Samedi     Magical  Mage  Ranged,         High Crowd Control
# 73          Merlin     Magical  Mage  Ranged,           High Area Damage
# 39       Discordia     Magical  Mage  Ranged,           High Area Damage
# 32         Chronos     Magical  Mage  Ranged,       Medium Crowd Control
# 44           Freya     Magical  Mage   Melee,           High Area Damage
# 50           Hades     Magical  Mage  Ranged,               High Defense
# 53             Hel     Magical  Mage  Ranged,           High Area Damage
# 41            Eset     Magical  Mage  Ranged,           High Area Damage
# 120      Zhong Kui     Magical  Mage  Ranged,           High Area Damage
# 86      Persephone        None  Mage  Magical           High Area Damage
# 83          Olorun     Magical  Mage  Ranged,          High Attack Speed
# 105   The Morrigan     Magical  Mage  Ranged,           High Area Damage
# 7         Ao Kuang     Magical  Mage   Melee,  High Single Target Damage
#
#                       Pro2                 Pro3  Health  HealthPerLevel  \
# 66                  Pusher                 None     532              79
# 54      High Crowd Control                 None     532              71
# 51    Medium Crowd Control                 None     560              70
# 60           High Mobility                 None     560              74
# 28           High Mobility                 None     574              84
# 99           High Mobility                 None     560              79
# 93                    None                 None     511              79
# 8                     None                 None     532              71
# 108                   None                 None     560              81
# 89           High Mobility                 None     539              84
# 88                  Pusher                 None     539              71
# 87                    None                 None     532              70
# 81                    None                 None     560              79
# 113                 Pusher                 None     532              75
# 80                    None                 None     511              79
# 118                   None                 None     560              81
# 107                   None                 None     511              79
# 74                    None                 None     602              81
# 1                     None                 None     504              75
# 119                   None                 None     532              75
# 3                     None                 None     630              79
# 6                     None                 None     532              74
# 17                    None                 None     560              77
# 20            High Sustain   Medium Area Damage     532              84
# 73                    None                 None     518              79
# 39                    None                 None     518              71
# 32           High Mobility                 None     560              79
# 44    Medium Crowd Control                 None     567              84
# 50            High Sustain                 None     665              89
# 53            High Sustain                 None     574              70
# 41      High Crowd Control                 None     511              71
# 120   Medium Crowd Control                 None     630              89
# 86                    None                 None     518              79
# 83                    None                 None     630              79
# 105                   None                 None     560              79
# 7                     None                 None     560              86
#
#      HealthPerFive  HP5PerLevel  Mana  ManaPerLevel  ManaPerFive  MP5PerLevel  \
# 66               7         0.46   265            45          5.0         0.45
# 54               6         0.45   265            45          4.8         0.41
# 51               6         0.45   298            56          4.9         0.40
# 60               6         0.45   350            58          5.0         0.45
# 28               6         0.45   310            48          5.5         0.44
# 99               6         0.45   300            57          4.9         0.40
# 93               6         0.45   298            56          4.9         0.40
# 8                6         0.45   240            43          4.8         0.41
# 108              7         0.50   300            55          5.0         0.44
# 89               6         0.45   255            43          4.6         0.46
# 88               7         0.48   255            48          4.8         0.44
# 87               6         0.50   245            40          4.6         0.40
# 81               7         0.45   265            43          4.6         0.43
# 113              7         0.48   245            40          4.8         0.45
# 80               8         0.60   250            38          5.0         0.40
# 118              7         0.47   280            55          4.7         0.44
# 107              6         0.45   245            49          4.6         0.44
# 74               8         0.48   250            55          4.8         0.44
# 1                7         0.47   255            45          4.7         0.37
# 119              6         0.45   245            44          4.6         0.45
# 3                6         0.45   265            55          4.9         0.42
# 6                7         0.45   280            58          4.8         0.36
# 17               8         0.50   280            50          5.0         0.60
# 20               7         0.60   300            44          5.0         0.45
# 73               6         0.48   250            55          4.8         0.44
# 39               7         0.45   280            51          5.0         0.43
# 32               7         0.48   240            42          4.4         0.44
# 44               7         0.52   220            37          4.5         0.39
# 50               5         0.54   265            53          5.0         0.36
# 53               5         0.43   300            57          5.0         0.45
# 41               6         0.45   280            51          4.8         0.43
# 120              6         0.44   250            47          4.8         0.45
# 86               7         0.45   280            55          5.0         0.42
# 83               7         0.45   240            58          5.0         0.40
# 105             10         0.70   250            38          4.5         0.40
# 7               10         0.70   240            38          4.8         0.41
#
#      PhysicalProtection  PhysicalProtectionPerLevel  MagicProtection  \
# 66                 18.2                         3.2             38.4
# 54                 12.6                         2.9             38.4
# 51                 12.6                         2.8             38.4
# 60                 11.2                         2.8             38.4
# 28                 15.4                         2.9             38.4
# 99                 12.6                         2.8             38.4
# 93                 12.6                         2.8             38.4
# 8                  12.6                         2.9             38.4
# 108                18.2                         2.9             38.4
# 89                 12.6                         3.3             38.4
# 88                 14.0                         3.2             38.4
# 87                 11.2                         2.8             38.4
# 81                 12.6                         2.9             38.4
# 113                18.2                         3.2             38.4
# 80                 25.2                         2.8             38.4
# 118                16.8                         3.2             38.4
# 107                12.6                         2.8             38.4
# 74                 19.6                         3.2             38.4
# 1                  15.4                         2.8             38.4
# 119                11.2                         2.9             38.4
# 3                  18.2                         2.9             38.4
# 6                  14.0                         2.7             38.4
# 17                 15.4                         2.9             38.4
# 20                 25.2                         2.8             38.4
# 73                 14.0                         3.2             38.4
# 39                 12.6                         2.9             38.4
# 32                 15.4                         3.1             38.4
# 44                 19.6                         3.0             38.4
# 50                 25.2                         2.8             38.4
# 53                 12.6                         2.8             38.4
# 41                 12.6                         2.9             38.4
# 120                11.2                         2.8             38.4
# 86                 12.6                         2.9             38.4
# 83                 18.2                         3.2             38.4
# 105                16.8                         3.2             38.4
# 7                  16.8                         3.2             38.4
#
#      MagicProtectionPerLevel  AttackSpeed  AttackSpeedPerLevel  \
# 66                       1.2         0.87                0.008
# 54                       1.2         0.90                0.009
# 51                       1.2         0.86                0.008
# 60                       1.2         1.00                0.008
# 28                       1.2         1.00                0.010
# 99                       1.2         1.00                0.018
# 93                       1.2         1.00                0.008
# 8                        1.2         0.87                0.008
# 108                      1.2         0.88                0.009
# 89                       1.2         0.87                0.008
# 88                       1.2         0.88                0.009
# 87                       1.2         0.87                0.010
# 81                       1.2         1.00                0.017
# 113                      1.2         0.90                0.010
# 80                       1.2         1.00                0.008
# 118                      1.2         1.00                0.012
# 107                      1.2         1.00                0.012
# 74                       1.2         1.00                0.008
# 1                        1.2         1.00                0.012
# 119                      1.2         0.95                0.009
# 3                        1.2         0.86                0.008
# 6                        1.2         0.86                0.009
# 17                       1.2         0.95                0.010
# 20                       1.2         0.90                0.007
# 73                       1.2         1.00                0.008
# 39                       1.2         0.90                0.009
# 32                       1.2         1.00                0.015
# 44                       1.2         0.95                0.019
# 50                       1.2         0.95                0.010
# 53                       1.2         0.86                0.008
# 41                       1.2         1.00                0.000
# 120                      1.2         0.86                0.009
# 86                       1.2         0.95                0.009
# 83                       1.2         1.05                0.016
# 105                      1.2         0.87                0.009
# 7                        1.2         1.00                0.020
#
#      AutoAttackDamage  AutoAttackDamagePerLevel  Speed
# 66               34.0                      1.45    360
# 54               34.0                      1.45    365
# 51               34.0                      1.45    355
# 60               34.0                      1.45    360
# 28               32.0                      1.45    355
# 99               34.0                      1.45    370
# 93               34.0                      1.45    355
# 8                32.0                      1.45    355
# 108              34.0                      1.50    360
# 89               34.0                      1.50    355
# 88               34.0                      1.50    360
# 87               35.0                      1.50    360
# 81               35.0                      1.50    355
# 113              34.0                      1.50    360
# 80               34.0                      1.50    360
# 118              35.0                      1.50    355
# 107              32.0                      1.50    355
# 74               35.0                      1.50    365
# 1                34.0                      1.50    355
# 119              35.0                      1.50    360
# 3                35.0                      1.50    365
# 6                35.0                      1.50    360
# 17               35.0                      1.50    365
# 20               34.0                      1.50    360
# 73               34.0                      1.50    355
# 39               34.0                      1.50    360
# 32               40.0                      1.50    360
# 44               35.0                      1.50    375
# 50               32.0                      1.50    365
# 53               33.0                      1.50    355
# 41               35.0                      1.50    360
# 120              33.0                      1.50    360
# 86               34.0                      1.70    360
# 83               32.0                      1.90    370
# 105              34.0                      2.40    365
# 7                35.0                      2.40    375

# %%
def Plot_stat_Damage_type(k):
    fig, ax = plt.subplots(1, 2, figsize=(25,5)) 

    min_ = dataset[k].min()
    max_ = dataset[k].max()

    A = dataset[k][dataset.Damage_Type=='Physical'].values
    B = dataset[k][dataset.Damage_Type=='Magical'].values

    data = [A, B]
    labels = ['Physical', 'Magical']
    color = ['Red', 'Blue']

    for i, x in enumerate(data):
        ax[i].set_xlim(min_, max_)
        ax[i].set_title(labels[i])
        ax[i].hist(x, len(x), color = color[i])
        
    plt.show()
    
def Plot_stat_Range(k):
    
    fig, ax = plt.subplots(1, 2, figsize=(25,5)) 

    min_ = dataset[k].min()
    max_ = dataset[k].max()

    A = dataset[k][dataset.Range=='Melee,'].values
    B = dataset[k][dataset.Range=='Ranged,'].values

    data = [A, B]
    labels = ['Melee', 'Ranged']
    color = ['Red', 'Blue']

    for i, x in enumerate(data):
        ax[i].set_xlim(min_, max_)
        ax[i].set_title(labels[i])
        ax[i].hist(x, len(x), color = color[i])
        
    plt.show()

# %%
def Plot_stat_Damage_type(k):
    fig, ax = plt.subplots(1, 2, figsize=(25,5)) 

    min_ = dataset[k].min()
    max_ = dataset[k].max()

    A = dataset[k][dataset.Damage_Type=='Physical'].values
    B = dataset[k][dataset.Damage_Type=='Magical'].values

    data = [A, B]
    labels = ['Physical', 'Magical']
    color = ['Red', 'Blue']

    for i, x in enumerate(data):
        ax[i].set_xlim(min_, max_)
        ax[i].set_title(labels[i])
        ax[i].hist(x, len(x), color = color[i])
        
    plt.savefig('images/AAPL_DT.jpeg')
    plt.show()

# %%
Plot_stat_Damage_type('AutoAttackDamagePerLevel')

# %%
for stat in stats:
    print(stat)
    Plot_stat_Damage_type(stat)
# Out:
# Health
# HealthPerLevel
# HealthPerFive
# HP5PerLevel
# Mana
# ManaPerLevel
# ManaPerFive
# MP5PerLevel
# PhysicalProtection
# PhysicalProtectionPerLevel
# AttackSpeed
# AttackSpeedPerLevel
# AutoAttackDamage
# AutoAttackDamagePerLevel
# Speed

# %% [markdown]
# ###### For checking the stats based on damage types there isnt as much intersting results as for classes
#
# Looking through the only really noteworthy stat difference are those related to Auto Attacks.
#
# In smite auto attacks are one of two types of damage, the other being ability damage, however the later doesnt rely on the base stats of the gods so it ahs been ommited.
#
# In terms of the analysis we see that there is a clear biased towards pysical based gods having much better auto attacks than there magical counterparts. This can be seen in all four of the stats related to attack speed, most distinctly in Auto attack damage per level.
#
# ![alt text](images/AAPL_DT.jpeg "")
#
# Only a few gods are able to match the physical gods (these are the auto attack focused mages in the game, where there are four to speak of)

# %%
for stat in stats:
    print(stat)
    Plot_stat_Range(stat)
# Out:
# Health
# HealthPerLevel
# HealthPerFive
# HP5PerLevel
# Mana
# ManaPerLevel
# ManaPerFive
# MP5PerLevel
# PhysicalProtection
# PhysicalProtectionPerLevel
# AttackSpeed
# AttackSpeedPerLevel
# AutoAttackDamage
# AutoAttackDamagePerLevel
# Speed
