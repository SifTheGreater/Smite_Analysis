# %%
import sqlite3

sqliteConnection = sqlite3.connect('Smite.db')
cursor = sqliteConnection.cursor()

# %% [markdown]
# # ranked joust

# %%
drop_command = """

DROP TABLE Joust_Ranked;

"""
cursor.execute(drop_command)

sql_command = """CREATE TABLE Joust_Ranked( 
Account_Level INTEGER, 
ActiveId1 INTEGER,
ActiveId2 INTEGER,
ActiveId3 INTEGER,
ActiveId4 INTEGER,
ActivePlayerId INTEGER,
Assists INTEGER,
Ban1 VARCHAR(255),
Ban10 VARCHAR(255),
Ban10Id INTEGER,
Ban11 VARCHAR(255),
Ban11Id INTEGER,
Ban12 VARCHAR(255),
Ban12Id INTEGER,
Ban1Id INTEGER,
Ban2 VARCHAR(255),
Ban2Id INTEGER,
Ban3 VARCHAR(255),
Ban3Id INTEGER,
Ban4 VARCHAR(255),
Ban4Id INTEGER,
Ban5 VARCHAR(255),
Ban5Id INTEGER,
Ban6 VARCHAR(255),
Ban6Id INTEGER,
Ban7 VARCHAR(255),
Ban7Id INTEGER,
Ban8 VARCHAR(255),
Ban8Id INTEGER,
Ban9 VARCHAR(255),
Ban9Id INTEGER,
Camps_Cleared INTEGER,
Conquest_Losses INTEGER,
Conquest_Points INTEGER,
Conquest_Tier INTEGER,
Conquest_Wins INTEGER,
Damage_Bot INTEGER,
Damage_Done_In_Hand INTEGER,
Damage_Done_Magical INTEGER,
Damage_Done_Physical INTEGER,
Damage_Mitigated INTEGER,
Damage_Player INTEGER,
Damage_Taken INTEGER,
Damage_Taken_Magical INTEGER,
Damage_Taken_Physical INTEGER,
Deaths INTEGER,
Distance_Traveled INTEGER,
Duel_Losses INTEGER,
Duel_Points INTEGER,
Duel_Tier INTEGER,
Duel_Wins INTEGER,
Entry_Datetime VARCHAR(255),
Final_Match_Level INTEGER,
First_Ban_Side VARCHAR(255),
GodId INTEGER,
Gold_Earned INTEGER,
Gold_Per_Minute INTEGER,
Healing INTEGER,
Healing_Bot INTEGER,
Healing_Player_Self INTEGER,
ItemId1 INTEGER,
ItemId2 INTEGER,
ItemId3 INTEGER,
ItemId4 INTEGER,
ItemId5 INTEGER,
ItemId6 INTEGER,
Item_Active_1 VARCHAR(255),
Item_Active_2 VARCHAR(255),
Item_Active_3 VARCHAR(255),
Item_Active_4 VARCHAR(255),
Item_Purch_1 VARCHAR(255),
Item_Purch_2 VARCHAR(255),
Item_Purch_3 VARCHAR(255),
Item_Purch_4 VARCHAR(255),
Item_Purch_5 VARCHAR(255),
Item_Purch_6 VARCHAR(255),
Joust_Losses INTEGER,
Joust_Points INTEGER,
Joust_Tier INTEGER,
Joust_Wins INTEGER,
Killing_Spree INTEGER,
Kills_Bot INTEGER,
Kills_Double INTEGER,
Kills_Fire_Giant INTEGER,
Kills_First_Blood INTEGER,
Kills_Gold_Fury INTEGER,
Kills_Penta INTEGER,
Kills_Phoenix INTEGER,
Kills_Player INTEGER,
Kills_Quadra INTEGER,
Kills_Siege_Juggernaut INTEGER,
Kills_Single INTEGER,
Kills_Triple INTEGER,
Kills_Wild_Juggernaut INTEGER,
Map_Game VARCHAR(255),
Mastery_Level INTEGER,
Match INTEGER,
Match_Duration INTEGER,
-- MergedPlayers LONGBLOB,
Minutes INTEGER,
Multi_kill_Max INTEGER,
Objective_Assists INTEGER,
PartyId INTEGER,
Rank_Stat_Conquest DECIMAL(4, 5),
Rank_Stat_Duel DECIMAL(4, 5),
Rank_Stat_Joust DECIMAL(4, 5),
Reference_Name VARCHAR(255),
Region VARCHAR(255),
Role VARCHAR(255),
Skin VARCHAR(255),
SkinId INTEGER,
Structure_Damage INTEGER,
Surrendered INTEGER,
TaskForce INTEGER,
Team1Score INTEGER,
Team2Score INTEGER,
TeamId INTEGER,
Team_Name VARCHAR(255),
Time_Dead_Seconds INTEGER,
Time_In_Match_Seconds INTEGER,
Towers_Destroyed INTEGER,
Wards_Placed INTEGER,
Win_Status VARCHAR(255),
Winning_TaskForce INTEGER,
hasReplay CHAR(1),
hz_gamer_tag VARCHAR(255),
hz_player_name VARCHAR(255),
match_queue_id INTEGER,
name VARCHAR(255),
playerId VARCHAR(255),
playerName VARCHAR(255),
playerPortalId INTEGER,
playerPortalUserId INTEGER,
ret_msg VARCHAR(255),
Controller VARCHAR(255)
);"""


cursor.execute(sql_command)

# %% [markdown]
# # ranked conquest

# %%
drop_command = """

DROP TABLE Conq_Ranked;

"""
cursor.execute(drop_command)

sql_command = """CREATE TABLE Conq_Ranked( 
Account_Level INTEGER, 
ActiveId1 INTEGER,
ActiveId2 INTEGER,
ActiveId3 INTEGER,
ActiveId4 INTEGER,
ActivePlayerId INTEGER,
Assists INTEGER,
Ban1 VARCHAR(255),
Ban10 VARCHAR(255),
Ban10Id INTEGER,
Ban11 VARCHAR(255),
Ban11Id INTEGER,
Ban12 VARCHAR(255),
Ban12Id INTEGER,
Ban1Id INTEGER,
Ban2 VARCHAR(255),
Ban2Id INTEGER,
Ban3 VARCHAR(255),
Ban3Id INTEGER,
Ban4 VARCHAR(255),
Ban4Id INTEGER,
Ban5 VARCHAR(255),
Ban5Id INTEGER,
Ban6 VARCHAR(255),
Ban6Id INTEGER,
Ban7 VARCHAR(255),
Ban7Id INTEGER,
Ban8 VARCHAR(255),
Ban8Id INTEGER,
Ban9 VARCHAR(255),
Ban9Id INTEGER,
Camps_Cleared INTEGER,
Conquest_Losses INTEGER,
Conquest_Points INTEGER,
Conquest_Tier INTEGER,
Conquest_Wins INTEGER,
Damage_Bot INTEGER,
Damage_Done_In_Hand INTEGER,
Damage_Done_Magical INTEGER,
Damage_Done_Physical INTEGER,
Damage_Mitigated INTEGER,
Damage_Player INTEGER,
Damage_Taken INTEGER,
Damage_Taken_Magical INTEGER,
Damage_Taken_Physical INTEGER,
Deaths INTEGER,
Distance_Traveled INTEGER,
Duel_Losses INTEGER,
Duel_Points INTEGER,
Duel_Tier INTEGER,
Duel_Wins INTEGER,
Entry_Datetime VARCHAR(255),
Final_Match_Level INTEGER,
First_Ban_Side VARCHAR(255),
GodId INTEGER,
Gold_Earned INTEGER,
Gold_Per_Minute INTEGER,
Healing INTEGER,
Healing_Bot INTEGER,
Healing_Player_Self INTEGER,
ItemId1 INTEGER,
ItemId2 INTEGER,
ItemId3 INTEGER,
ItemId4 INTEGER,
ItemId5 INTEGER,
ItemId6 INTEGER,
Item_Active_1 VARCHAR(255),
Item_Active_2 VARCHAR(255),
Item_Active_3 VARCHAR(255),
Item_Active_4 VARCHAR(255),
Item_Purch_1 VARCHAR(255),
Item_Purch_2 VARCHAR(255),
Item_Purch_3 VARCHAR(255),
Item_Purch_4 VARCHAR(255),
Item_Purch_5 VARCHAR(255),
Item_Purch_6 VARCHAR(255),
Joust_Losses INTEGER,
Joust_Points INTEGER,
Joust_Tier INTEGER,
Joust_Wins INTEGER,
Killing_Spree INTEGER,
Kills_Bot INTEGER,
Kills_Double INTEGER,
Kills_Fire_Giant INTEGER,
Kills_First_Blood INTEGER,
Kills_Gold_Fury INTEGER,
Kills_Penta INTEGER,
Kills_Phoenix INTEGER,
Kills_Player INTEGER,
Kills_Quadra INTEGER,
Kills_Siege_Juggernaut INTEGER,
Kills_Single INTEGER,
Kills_Triple INTEGER,
Kills_Wild_Juggernaut INTEGER,
Map_Game VARCHAR(255),
Mastery_Level INTEGER,
Match INTEGER,
Match_Duration INTEGER,
-- MergedPlayers LONGBLOB,
Minutes INTEGER,
Multi_kill_Max INTEGER,
Objective_Assists INTEGER,
PartyId INTEGER,
Rank_Stat_Conquest DECIMAL(4, 5),
Rank_Stat_Duel DECIMAL(4, 5),
Rank_Stat_Joust DECIMAL(4, 5),
Reference_Name VARCHAR(255),
Region VARCHAR(255),
Role VARCHAR(255),
Skin VARCHAR(255),
SkinId INTEGER,
Structure_Damage INTEGER,
Surrendered INTEGER,
TaskForce INTEGER,
Team1Score INTEGER,
Team2Score INTEGER,
TeamId INTEGER,
Team_Name VARCHAR(255),
Time_Dead_Seconds INTEGER,
Time_In_Match_Seconds INTEGER,
Towers_Destroyed INTEGER,
Wards_Placed INTEGER,
Win_Status VARCHAR(255),
Winning_TaskForce INTEGER,
hasReplay CHAR(1),
hz_gamer_tag VARCHAR(255),
hz_player_name VARCHAR(255),
match_queue_id INTEGER,
name VARCHAR(255),
playerId VARCHAR(255),
playerName VARCHAR(255),
playerPortalId INTEGER,
playerPortalUserId INTEGER,
ret_msg VARCHAR(255),
Controller VARCHAR(255)
);"""


cursor.execute(sql_command)

# %% [markdown]
# # Ranked Duel

# %%
drop_command = """

DROP TABLE Duel_Ranked;

"""
cursor.execute(drop_command)

sql_command = """CREATE TABLE Duel_Ranked( 
Account_Level INTEGER, 
ActiveId1 INTEGER,
ActiveId2 INTEGER,
ActiveId3 INTEGER,
ActiveId4 INTEGER,
ActivePlayerId INTEGER,
Assists INTEGER,
Ban1 VARCHAR(255),
Ban10 VARCHAR(255),
Ban10Id INTEGER,
Ban11 VARCHAR(255),
Ban11Id INTEGER,
Ban12 VARCHAR(255),
Ban12Id INTEGER,
Ban1Id INTEGER,
Ban2 VARCHAR(255),
Ban2Id INTEGER,
Ban3 VARCHAR(255),
Ban3Id INTEGER,
Ban4 VARCHAR(255),
Ban4Id INTEGER,
Ban5 VARCHAR(255),
Ban5Id INTEGER,
Ban6 VARCHAR(255),
Ban6Id INTEGER,
Ban7 VARCHAR(255),
Ban7Id INTEGER,
Ban8 VARCHAR(255),
Ban8Id INTEGER,
Ban9 VARCHAR(255),
Ban9Id INTEGER,
Camps_Cleared INTEGER,
Conquest_Losses INTEGER,
Conquest_Points INTEGER,
Conquest_Tier INTEGER,
Conquest_Wins INTEGER,
Damage_Bot INTEGER,
Damage_Done_In_Hand INTEGER,
Damage_Done_Magical INTEGER,
Damage_Done_Physical INTEGER,
Damage_Mitigated INTEGER,
Damage_Player INTEGER,
Damage_Taken INTEGER,
Damage_Taken_Magical INTEGER,
Damage_Taken_Physical INTEGER,
Deaths INTEGER,
Distance_Traveled INTEGER,
Duel_Losses INTEGER,
Duel_Points INTEGER,
Duel_Tier INTEGER,
Duel_Wins INTEGER,
Entry_Datetime VARCHAR(255),
Final_Match_Level INTEGER,
First_Ban_Side VARCHAR(255),
GodId INTEGER,
Gold_Earned INTEGER,
Gold_Per_Minute INTEGER,
Healing INTEGER,
Healing_Bot INTEGER,
Healing_Player_Self INTEGER,
ItemId1 INTEGER,
ItemId2 INTEGER,
ItemId3 INTEGER,
ItemId4 INTEGER,
ItemId5 INTEGER,
ItemId6 INTEGER,
Item_Active_1 VARCHAR(255),
Item_Active_2 VARCHAR(255),
Item_Active_3 VARCHAR(255),
Item_Active_4 VARCHAR(255),
Item_Purch_1 VARCHAR(255),
Item_Purch_2 VARCHAR(255),
Item_Purch_3 VARCHAR(255),
Item_Purch_4 VARCHAR(255),
Item_Purch_5 VARCHAR(255),
Item_Purch_6 VARCHAR(255),
Joust_Losses INTEGER,
Joust_Points INTEGER,
Joust_Tier INTEGER,
Joust_Wins INTEGER,
Killing_Spree INTEGER,
Kills_Bot INTEGER,
Kills_Double INTEGER,
Kills_Fire_Giant INTEGER,
Kills_First_Blood INTEGER,
Kills_Gold_Fury INTEGER,
Kills_Penta INTEGER,
Kills_Phoenix INTEGER,
Kills_Player INTEGER,
Kills_Quadra INTEGER,
Kills_Siege_Juggernaut INTEGER,
Kills_Single INTEGER,
Kills_Triple INTEGER,
Kills_Wild_Juggernaut INTEGER,
Map_Game VARCHAR(255),
Mastery_Level INTEGER,
Match INTEGER,
Match_Duration INTEGER,
-- MergedPlayers LONGBLOB,
Minutes INTEGER,
Multi_kill_Max INTEGER,
Objective_Assists INTEGER,
PartyId INTEGER,
Rank_Stat_Conquest DECIMAL(4, 5),
Rank_Stat_Duel DECIMAL(4, 5),
Rank_Stat_Joust DECIMAL(4, 5),
Reference_Name VARCHAR(255),
Region VARCHAR(255),
Role VARCHAR(255),
Skin VARCHAR(255),
SkinId INTEGER,
Structure_Damage INTEGER,
Surrendered INTEGER,
TaskForce INTEGER,
Team1Score INTEGER,
Team2Score INTEGER,
TeamId INTEGER,
Team_Name VARCHAR(255),
Time_Dead_Seconds INTEGER,
Time_In_Match_Seconds INTEGER,
Towers_Destroyed INTEGER,
Wards_Placed INTEGER,
Win_Status VARCHAR(255),
Winning_TaskForce INTEGER,
hasReplay CHAR(1),
hz_gamer_tag VARCHAR(255),
hz_player_name VARCHAR(255),
match_queue_id INTEGER,
name VARCHAR(255),
playerId VARCHAR(255),
playerName VARCHAR(255),
playerPortalId INTEGER,
playerPortalUserId INTEGER,
ret_msg VARCHAR(255),
Controller VARCHAR(255)
);"""


cursor.execute(sql_command)

# %% [markdown]
# # Items

# %%
drop_command = """

DROP TABLE Items;

"""
cursor.execute(drop_command)

sql_command = """CREATE TABLE Items( 

    blank VARCHAR(255),
    ActiveFlag CHAR(1),
    Attack_Speed INTEGER,
    Basic_Attack_Damage INTEGER,
    ChildItemId INTEGER,
    Cooldown_Reduction INTEGER,
    Critical_Strike_Chance VARCGAR(255),
    Crowd_Control_Reduction INTEGER,
    Damage_Reduction INTEGER,
    Description VARCHAR(255),
    DeviceName VARCHAR(255),
    Glyph CHAR(1),
    HP5 INTEGER,
    HP5_and_MP5 INTEGER,
    Health INTEGER,
    IconId INTEGER,
    ItemId INTEGER,
    ItemTier INTEGER,
    MP5 INTEGER,
    Magical_Lifesteal INTEGER,
    Magical_Penetration INTEGER,
    Magical_Power INTEGER,
    Magical_Protections INTEGER,
    Mana INTEGER,
    Maximum_Health INTEGER,
    Movement_Speed INTEGER,
    Penetration INTEGER,
    Physical_Critical Strike Chance INTEGER,
    Physical_Lifesteal INTEGER,
    Physical_Penetration INTEGER,
    Physical_Power INTEGER,
    Physical_Protection INTEGER,
    Price INTEGER,
    Protections INTEGER,
    RestrictedRoles VARCHAR(255),
    RootItemId INTEGER,
    SecondaryDescription VARCHAR(255),
    ShortDesc VARCHAR(255),
    StartingItem VARCHAR(255),
    Type VARCHAR(255),
    Unlocks_at_level_10 INTEGER,
    itemIcon_URL VARCHAR(255),
    ret_msg VARCHAR(255)
    
)"""

cursor.execute(sql_command)

# %% [markdown]
# # Gods

# %%
drop_command = """

DROP TABLE Gods;

"""
cursor.execute(drop_command)

sql_command = """CREATE TABLE Gods( 

Ability1 VARCHAR(255),
Ability2 VARCHAR(255), 
Ability3 VARCHAR(255),
Ability4 VARCHAR(255),
Ability5 VARCHAR(255),
AbilityId1 INTEGER,
AbilityId2 INTEGER,
AbilityId3 INTEGER,
AbilityId4 INTEGER,
AbilityId5 INTEGER,
AttackSpeed DECIMAL(2, 2),
AttackSpeedPerLevel DECIMAL(2, 3),
AutoBanned CHAR(1),
Cons VARCHAR(255),
HP5PerLevel DECIMAL(2, 2),
Health INTEGER,
HealthPerFive INTEGER,
HealthPerLevel INTEGER,
Lore VARCHAR(5000),
MP5PerLevel DECIMAL(2, 2),
MagicProtection INTEGER,
MagicProtectionPerLevel DECIMAL(2, 2),
MagicalPower INTEGER,
MagicalPowerPerLevel INTEGER,
Mana INTEGER,
ManaPerFive INTEGER,
ManaPerLevel INTEGER,
Name INTEGER,
OnFreeRotation CHAR(1),
Pantheon VARCHAR(255),
PhysicalPower INTEGER,
PhysicalPowerPerLevel INTEGER,
PhysicalProtection INTEGER,
PhysicalProtectionPerLevel INTEGER,
Pros VARCHAR(255),
Roles VARCHAR(255),
Speed INTEGER,
Title VARCHAR(255),
Type VARCHAR(255),
godAbility1_URL VARCHAR(255),
godAbility2_URL VARCHAR(255),
godAbility3_URL VARCHAR(255),
godAbility4_URL VARCHAR(255),
godAbility5_URL VARCHAR(255),
godCard_URL VARCHAR(255),
godIcon_URL VARCHAR(255),
id INTEGER,
latestGod CHAR(1),
ret_msg VARCHAR(255)
  
)"""

cursor.execute(sql_command)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [3], in <cell line: 6>()
#       1 drop_command = """
#       2
#       3 DROP TABLE Gods;
#       4
#       5 """
# ----> 6 cursor.execute(drop_command)
#       8 sql_command = """CREATE TABLE Gods(
#       9
#      10 Ability1 VARCHAR(255),
#    (...)
#      59
#      60 )"""
#      62 cursor.execute(sql_command)
#
# OperationalError: database is locked

# %%
sqliteConnection.commit()
cursor.close()
